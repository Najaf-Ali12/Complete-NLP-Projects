# %% [markdown]
# <a href="https://colab.research.google.com/github/Najaf-Ali12/LLM-Hugging-Face/blob/main/running_streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 2: Install Streamlit and Localtunnel
# !pip install -q streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 115.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 108.7 MB/s eta 0:00:00
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧
# added 22 packages in 3s
# ⠧
# ⠧3 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧

# %%
from huggingface_hub import hf_hub_download

# This pulls the clean, uncorrupted file directly from your HF account
hf_hub_download(
    repo_id="NajafAli01/my-sentiment-model",
    filename="model.safetensors",
    local_dir="."
)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: reconstructing file:   0%|          |  0.00B /  268MB
# model.safetensors: downloading bytes:           |  0.00B
# '/content/model.safetensors'

# %%
# !pip install pyngrok
# !ngrok config add-authtoken YOUR_NGROK_AUTHTOKEN
# Out:
# ...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import getpass
from pyngrok import ngrok

# This creates a hidden input box (like a password field) when executed
token = getpass.getpass("Enter your Ngrok Authtoken: ")
ngrok.set_auth_token(token)

public_url = ngrok.connect(8503)
print(f"Your app is live at: {public_url}")
# !streamlit run app.py --server.port 8503
# Out:
# Enter your Ngrok Authtoken: ··········
# Your app is live at: NgrokTunnel: "https://decorated-safeness-passover.ngrok-free.dev" -> "http://localhost:8503"
#
# ...
#
# 2026-09-15 14:02:53.900 Uvicorn server started on :::8503
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8503
#   Network URL: http://172.28.0.12:8503
#   External URL: http://34.87.28.55:8503
#
# Loading weights: 100% 104/104 [00:00<00:00, 14896.27it/s]
#   Stopping...
#   Stopping...
